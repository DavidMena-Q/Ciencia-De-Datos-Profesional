# %%
import pandas as pd

# %%
series = pd.Series( [5, 10, 15, 20, 25] )
series
# Out:
# 0     5
# 1    10
# 2    15
# 3    20
# 4    25
# dtype: int64

# %%
type(series)
# Out:
# pandas.core.series.Series

# %%
series[3]
# Out:
# 20

# %%
cad = pd.Series( ['d', 'a', 'r', 'i', 'c'] )
cad
# Out:
# 0    d
# 1    a
# 2    r
# 3    i
# 4    c
# dtype: object

# %%
lst = ['Hola', 'mundo', 'robótico']
df = pd.DataFrame(lst)
print(df)
# Out:
#           0
# 0      Hola
# 1     mundo
# 2  robótico

# %%
data = {'Nombre': ['Juan', 'Lupe', 'Arlo', 'Prro'], 
        'Edad': [34, 23, 12, 76], 
        'País': ['Ec', 'Co', 'Br', 'Mx']}
df = pd.DataFrame(data)
df
# Out:
#   Nombre  Edad País
# 0   Juan    34   Ec
# 1   Lupe    23   Co
# 2   Arlo    12   Br
# 3   Prro    76   Mx

# %%
print(df[['Nombre', 'País']])
# Out:
#   Nombre País
# 0   Juan   Ec
# 1   Lupe   Co
# 2   Arlo   Br
# 3   Prro   Mx

# %%
data = pd.read_csv('./CSV/canciones-2018.csv')
data.head(5)
# Out:
#                       id                          name       artists  \
# 0  6DCZcSspjsKoFjzjrWoCd                    God's Plan         Drake
# 1  3ee8Jmje8o58CHK66QrVC                          SAD!  XXXTENTACION
# 2  0e7ipj03S05BNilyu5bRz    rockstar (feat. 21 Savage)   Post Malone
# 3  3swc6WTsr7rl9DqQKQA55  Psycho (feat. Ty Dolla $ign)   Post Malone
# 4  2G7V7zsVDxg1yRsu7Ew9R                In My Feelings         Drake
#
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.754   0.449  7.0    -9.211   1.0       0.1090        0.0332
# 1         0.740   0.613  8.0    -4.880   1.0       0.1450        0.2580
# 2         0.587   0.535  5.0    -6.090   0.0       0.0898        0.1170
# 3         0.739   0.559  8.0    -8.011   1.0       0.1170        0.5800
# 4         0.835   0.626  1.0    -5.833   1.0       0.1250        0.0589
#
#    instrumentalness  liveness  valence    tempo  duration_ms  time_signature
# ...

# %%
artist = data.artists
artist[8]
# Out:
# 'Dua Lipa'

# %%
info = data.iloc[15]
info
# Out:
# id                     3GCdLUSnKSMJhs4Tj6CV3
# name                All The Stars (with SZA)
# artists                       Kendrick Lamar
# danceability                           0.698
# energy                                 0.633
# key                                      8.0
# loudness                              -4.946
# mode                                     1.0
# speechiness                           0.0597
# acousticness                          0.0605
# instrumentalness                    0.000194
# liveness                              0.0926
# valence                                0.552
# tempo                                 96.924
# duration_ms                         232187.0
# time_signature                           4.0
# Name: 15, dtype: object

# %%
len(data)
# Out:
# 100

# %%
data.tail()
# Out:
#                        id                               name       artists  \
# 95  630sXRhIcfwr2e4RdNtjK                  Rewrite The Stars     Zac Efron
# 96  2xmrfQpmS2iJExTlklLoA  I Miss You (feat. Julia Michaels)  Clean Bandit
# 97  5WvAo7DNuPRmk4APhdPzi                         No Brainer     DJ Khaled
# 98  1j4kHkkpqZRBwE0A4CN4Y        Dusk Till Dawn - Radio Edit          ZAYN
# 99  3EPXxR3ImUwfayaurPi3c                         Be Alright    Dean Lewis
#
#     danceability  energy   key  loudness  mode  speechiness  acousticness  \
# 95         0.684   0.619  10.0    -7.005   1.0       0.0386        0.0716
# 96         0.638   0.658   3.0    -6.318   1.0       0.0456        0.2450
# 97         0.552   0.760   0.0    -4.706   1.0       0.3420        0.0733
# 98         0.258   0.437  11.0    -6.593   0.0       0.0390        0.1010
# 99         0.553   0.586  11.0    -6.319   1.0       0.0362        0.6970
#
# ...

# %%
data.shape
# Out:
# (100, 16)

# %%
data.columns
# Out:
# Index(['id', 'name', 'artists', 'danceability', 'energy', 'key', 'loudness',
#        'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness',
#        'valence', 'tempo', 'duration_ms', 'time_signature'],
#       dtype='object')

# %%
data['tempo'].describe()
# Out:
# count    100.000000
# mean     119.904180
# std       28.795984
# min       64.934000
# 25%       95.730750
# 50%      120.116000
# 75%      140.022750
# max      198.075000
# Name: tempo, dtype: float64

# %%
data.sort_index(axis = 1, ascending = False)
# Out:
#     valence  time_signature    tempo  speechiness  \
# 0    0.3570             4.0   77.169       0.1090
# 1    0.4730             4.0   75.023       0.1450
# 2    0.1400             4.0  159.847       0.0898
# 3    0.4390             4.0  140.124       0.1170
# 4    0.3500             4.0   91.030       0.1250
# ..      ...             ...      ...          ...
# 95   0.2840             4.0  125.046       0.0386
# 96   0.3300             4.0  105.076       0.0456
# 97   0.6390             5.0  135.702       0.3420
# 98   0.0967             4.0  180.043       0.0390
# 99   0.4430             4.0  126.684       0.0362
#
#                                  name  mode  loudness  liveness   key  \
# 0                          God's Plan   1.0    -9.211    0.5520   7.0
# 1                                SAD!   1.0    -4.880    0.1230   8.0
# 2          rockstar (feat. 21 Savage)   0.0    -6.090    0.1310   5.0
# 3        Psycho (feat. Ty Dolla $ign)   1.0    -8.011    0.1120   8.0
# ...

# %%
data[['name', 'tempo', 'duration_ms']].sort_values('duration_ms', ascending=False)
# Out:
#                                   name    tempo  duration_ms
# 21                     Te Bot? - Remix   96.507     417920.0
# 42                          SICKO MODE  155.008     312820.0
# 73                     Walk It Talk It  145.905     276147.0
# 74               Him & I (with Halsey)   87.908     268867.0
# 29                             Perfect   95.050     263400.0
# ..                                 ...      ...          ...
# 18                           Moonlight  128.009     135090.0
# 22                                Mine  142.929     131064.0
# 38                             changes   64.934     121887.0
# 28                      Jocelyn Flores  134.021     119133.0
# 94  Everybody Dies In Their Nightmares  129.953      95467.0
#
# [100 rows x 3 columns]
