# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
dataset = pd.read_csv('./CSV/salarios.csv')
paises = ['VZ','MX','CO','BR','AR','US']
new_column = [paises[np.random.randint(0,len(paises))] for i in range(30)]
dataset['Pais'] = new_column
dataset['NormPaises'] = pd.factorize(dataset['Pais'])[0]
dataset.head()
# Out:
#    Aexperiencia  Salario Pais  NormPaises
# 0          10.0    42500   US           0
# 1           8.0    36302   BR           1
# 2           5.4    35000   US           0
# 3           2.5    18103   VZ           2
# 4           1.0    15000   MX           3

# %%
dataset.shape
# Out:
# (30, 4)

# %%
x = dataset[['Aexperiencia', 'NormPaises']]
y = dataset['Salario']

# %%
X_train, X_test, Y_train, Y_test = train_test_split(x, y, test_size=0.2, random_state=0)

# %%
regressor = LinearRegression()
regressor.fit(X_train, Y_train)
regressor.score(X_test, Y_test)
# Out:
# 0.7873455121038153

# %%
fig = plt.figure(dpi = 150)
ax = fig.add_subplot(projection='3d')
ax.scatter(X_train['Aexperiencia'],X_train['NormPaises'],Y_train,c='b',marker='s')
ax.scatter(X_train['Aexperiencia'],X_train['NormPaises'],regressor.predict(X_train),c='r',marker='o')
ax.set_xlabel('$Años de experiencia$')
ax.set_ylabel('$Pais Normalizado$')
ax.set_zlabel('$Salario$')
# Out:
# Text(0.5, 0, '$Salario$')

# %%
fig = plt.figure(dpi = 150)
ax = fig.add_subplot(projection='3d')
ax.scatter(X_test['Aexperiencia'],X_test['NormPaises'],Y_test,c='b',marker='+')
ax.scatter(X_train['Aexperiencia'],X_train['NormPaises'],regressor.predict(X_train),c='r', marker='|')
ax.set_xlabel('$Años de experiencia$')
ax.set_ylabel('$Pais Normalizado$')
ax.set_zlabel('$Salario$')
# Out:
# Text(0.5, 0, '$Salario$')
